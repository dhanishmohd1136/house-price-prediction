# %%
import sys
import os

sys.path.append(os.path.abspath('../'))

# %%
import pandas as pd
import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LassoCV

from src.preprocess import preprocess
from src.train import split_data
from src.evaluate import evaluate

df = pd.read_csv('../data/train.csv')
df = preprocess(df)

X_train, X_test, y_train, y_test = split_data(df)

model = Pipeline([
    ('scaler', StandardScaler()),
    ('lasso', LassoCV(cv=5, max_iter=5000))
])

model.fit(X_train, y_train)

results = evaluate(model, X_train, X_test, y_train, y_test)
print(results)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 7
#       3 from sklearn.pipeline import Pipeline
#       4 from sklearn.preprocessing import StandardScaler
#       5 from sklearn.linear_model import LassoCV
#       6
# ----> 7 from src.preprocess import preprocess
#       8 from src.train import split_data
#       9 from src.evaluate import evaluate
#      10
#
# ModuleNotFoundError: No module named 'src.preprocess'
